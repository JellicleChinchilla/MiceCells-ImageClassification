# %% [markdown]
# ## Preprocessing

# %%
import pickle
import tensorflow as tf

# %% [markdown]
# #### 28 Classes

# %%
import numpy as np
import pandas as pd
import os
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.resnet_v2 import ResNet152V2
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.model_selection import train_test_split
import cv2

# Set the path to the dataset directory
data_dir = 'data_processed/full_clean_image/'
#data_dir = "data_processed/clean_image"
#data_dir = "data_processed/full_cell_images"

# Load the cell boundaries data
cell_boundaries_raw = pd.read_csv('data_processed/cell_boundaries.csv.gz')

# Get a list of all the cluster folders
cluster_folders = [os.path.join(data_dir, f'cluster_{i}') for i in range(1, 29)]

# Create a list to hold the image data and corresponding labels
images = []
labels = []

# Loop through each cluster folder
for folder in cluster_folders:
    # Get a list of all the image file names in the folder
    file_names = os.listdir(folder)
    
    # Loop through each image file in the folder
    for file_name in file_names:
        # Extract the cell ID from the image file name
        cell_id = int(file_name.split('_')[1].split('.')[0])
        
        # Load the preprocessed image
        img = cv2.imread(os.path.join(folder, file_name))
        
        # Add the preprocessed image and label to the list
        images.append(img)
        labels.append(f'cluster_{folder.split("_")[-1]}')

# Convert the image and label lists to arrays
X = np.array(images)
y = np.array(labels)

# Split the data into training, validation, and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25)

# Create data generators for training, validation, and testing sets
train_datagen = ImageDataGenerator(rescale=1./255,
                                   rotation_range=20,
                                   width_shift_range=0.2,
                                   height_shift_range=0.2,
                                   shear_range=0.2,
                                   zoom_range=0.2,
                                   horizontal_flip=True)
val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow(X_train, y_train, batch_size=32)
val_generator = val_datagen.flow(X_val, y_val, batch_size=32)
test_generator = test_datagen.flow(X_test, y_test, batch_size=32)

# %% [markdown]
# #### 7 Classes

# %%
import numpy as np
import pandas as pd
import os
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.resnet_v2 import ResNet152V2
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.model_selection import train_test_split
import cv2

# Set the path to the dataset directory
data_dir = 'data_processed/full_clean_image/'

# Get a list of the cluster folders you want to include
cluster_folders = [
    os.path.join(data_dir, 'cluster_2'),
    os.path.join(data_dir, 'cluster_4'),
    os.path.join(data_dir, 'cluster_5'),
    os.path.join(data_dir, 'cluster_7'),
    os.path.join(data_dir, 'cluster_9'),
    os.path.join(data_dir, 'cluster_10'),
    os.path.join(data_dir, 'cluster_13')
]

# Create a list to hold the image data and corresponding labels
images = []
labels = []

# Loop through each cluster folder
for folder in cluster_folders:
    # Get a list of all the image file names in the folder
    file_names = os.listdir(folder)
    
    # Loop through each image file in the folder
    for file_name in file_names:
        # Extract the cell ID from the image file name
        cell_id = int(file_name.split('_')[1].split('.')[0])
        
        # Load the preprocessed image
        img = cv2.imread(os.path.join(folder, file_name))
        
        # Add the preprocessed image and label to the list
        images.append(img)
        labels.append(f'cluster_{folder.split("_")[-1]}')

# Convert the image and label lists to arrays
X = np.array(images)
y = np.array(labels)

# Split the data into training, validation, and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25)

# Create data generators for training, validation, and testing sets
train_datagen = ImageDataGenerator(rescale=1./255,
                                   rotation_range=20,
                                   width_shift_range=0.2,
                                   height_shift_range=0.2,
                                   shear_range=0.2,
                                   zoom_range=0.2,
                                   horizontal_flip=True)
val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow(X_train, y_train, batch_size=32)
val_generator = val_datagen.flow(X_val, y_val, batch_size=32)
test_generator = test_datagen.flow(X_test, y_test, batch_size=32)

# %% [markdown]
# #### 14 Classes

# %%
import numpy as np
import pandas as pd
import os
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.resnet_v2 import ResNet152V2
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.model_selection import train_test_split
import cv2

# Set the path to the dataset directory
data_dir = 'data_processed/full_clean_image/'

# Get a list of the cluster folders you want to include
cluster_folders = [
    os.path.join(data_dir, 'cluster_1'),
    os.path.join(data_dir, 'cluster_2'),
    os.path.join(data_dir, 'cluster_3'),
    os.path.join(data_dir, 'cluster_4'),
    os.path.join(data_dir, 'cluster_5'),
    os.path.join(data_dir, 'cluster_6'),
    os.path.join(data_dir, 'cluster_9'),
    os.path.join(data_dir, 'cluster_12'),
    os.path.join(data_dir, 'cluster_21'),
    os.path.join(data_dir, 'cluster_22'),
    os.path.join(data_dir, 'cluster_23'),
    os.path.join(data_dir, 'cluster_24'),
    os.path.join(data_dir, 'cluster_26'),
    os.path.join(data_dir, 'cluster_28')
]

# Create a list to hold the image data and corresponding labels
images = []
labels = []

# Loop through each cluster folder
for folder in cluster_folders:
    # Get a list of all the image file names in the folder
    file_names = os.listdir(folder)
    
    # Loop through each image file in the folder
    for file_name in file_names:
        # Extract the cell ID from the image file name
        cell_id = int(file_name.split('_')[1].split('.')[0])
        
        # Load the preprocessed image
        img = cv2.imread(os.path.join(folder, file_name))
        
        # Add the preprocessed image and label to the list
        images.append(img)
        labels.append(f'cluster_{folder.split("_")[-1]}')

# Convert the image and label lists to arrays
X = np.array(images)
y = np.array(labels)

# Split the data into training, validation, and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25)

# Create data generators for training, validation, and testing sets
train_datagen = ImageDataGenerator(rescale=1./255,
                                   rotation_range=20,
                                   width_shift_range=0.2,
                                   height_shift_range=0.2,
                                   shear_range=0.2,
                                   zoom_range=0.2,
                                   horizontal_flip=True)
val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow(X_train, y_train, batch_size=32)
val_generator = val_datagen.flow(X_val, y_val, batch_size=32)
test_generator = test_datagen.flow(X_test, y_test, batch_size=32)

# %% [markdown]
# ## ResNet150 Stratified 7 Classes

# %%
# Load the pre-trained ResNet152V2 model
resnet_model = ResNet152V2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

num_classes = 7

import logging
logging.getLogger('tensorflow').setLevel(logging.ERROR)

# Freeze all layers except the last few
for layer in resnet_model.layers[:-10]:
    layer.trainable = False

from tensorflow.keras.optimizers import SGD
from keras.layers.pooling import GlobalAveragePooling2D

# Build the classification head
model = Sequential()
model.add(resnet_model)
model.add(GlobalAveragePooling2D())
model.add(Dense(512, activation='relu'))
#model.add(Dropout(0.5))
model.add(Dense(len(cluster_folders), activation='softmax'))

model.compile(loss='categorical_crossentropy',
              optimizer=SGD(learning_rate=0.01, momentum=0.9),
              metrics=['accuracy'])

# Convert labels to one-hot encoding
from sklearn.preprocessing import LabelBinarizer
lb = LabelBinarizer()
y_train_encoded = lb.fit_transform(y_train)
y_val_encoded = lb.fit_transform(y_val)
y_test_encoded = lb.transform(y_test)

# Use one-hot encoded labels for training and testing
train_generator = train_datagen.flow(X_train, y_train_encoded, batch_size=32)
val_generator = val_datagen.flow(X_val, y_val_encoded, batch_size=32)
test_generator = test_datagen.flow(X_test, y_test_encoded, batch_size=32)

checkpoint = ModelCheckpoint('resnet150_7_622.h5',
                             save_best_only=True,
                             save_weights_only=False,
                             monitor='val_accuracy',
                             mode='max',
                             verbose=1)

history = model.fit(train_generator,
                    epochs=50,
                    steps_per_epoch=len(train_generator),
                    validation_data=test_generator,
                    validation_steps=len(val_generator),
                    callbacks=[checkpoint])

# Save the final trained model
model.save('resnet150_str_7_622.h5')

# Save the history object
with open('history_str_7_622.pkl', 'wb') as file_pi:
    pickle.dump(history.history, file_pi)
# Out:
# Epoch 1/50
# 260/260 [==============================] - ETA: 0s - loss: 1.7473 - accuracy: 0.3041
# Epoch 1: val_accuracy improved from -inf to 0.32841, saving model to resnet150_7_622.h5
# 260/260 [==============================] - 90s 321ms/step - loss: 1.7473 - accuracy: 0.3041 - val_loss: 1.7209 - val_accuracy: 0.3284
# Epoch 2/50
# 260/260 [==============================] - ETA: 0s - loss: 1.6811 - accuracy: 0.3292
# Epoch 2: val_accuracy did not improve from 0.32841
# 260/260 [==============================] - 81s 311ms/step - loss: 1.6811 - accuracy: 0.3292 - val_loss: 1.7169 - val_accuracy: 0.3107
# Epoch 3/50
# 260/260 [==============================] - ETA: 0s - loss: 1.6595 - accuracy: 0.3383
# Epoch 3: val_accuracy improved from 0.32841 to 0.34571, saving model to resnet150_7_622.h5
# 260/260 [==============================] - 80s 308ms/step - loss: 1.6595 - accuracy: 0.3383 - val_loss: 1.6709 - val_accuracy: 0.3457
# Epoch 4/50
# ...

# %%
# Save the history object
with open('history_str_7_622.pkl', 'wb') as file_pi:
    pickle.dump(history.history, file_pi)

# %%
# Load the best model
best_model = tf.keras.models.load_model("resnet150_str_7_622.h5")

# Evaluate the best model on test data
loss, accuracy = best_model.evaluate(test_generator)
print(f"Test loss: {loss}, Test accuracy: {accuracy}")
# Out:
# 87/87 [==============================] - 17s 171ms/step - loss: 1.6238 - accuracy: 0.3828
# Test loss: 1.6237837076187134, Test accuracy: 0.38284066319465637

# %%
import matplotlib.pyplot as plt

# Plot the training and validation accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['train', 'val'], loc='upper left')
plt.savefig('ResNet150V2_str_A7.png', dpi=300)
plt.show()

# Plot the training and validation loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['train', 'val'], loc='upper left')
plt.savefig('ResNet150V2_str_L7.png', dpi=300)
plt.show()

# %%
# Convert labels to one-hot encoding
from sklearn.preprocessing import LabelBinarizer
lb = LabelBinarizer()
y_train_encoded = lb.fit_transform(y_train)
y_test_encoded = lb.transform(y_test)

# Use one-hot encoded labels for training and testing
train_generator = train_datagen.flow(X_train, y_train_encoded, batch_size=32)
test_generator = test_datagen.flow(X_test, y_test_encoded, batch_size=32)

# Load the saved model
model = tf.keras.models.load_model('resnet150_str_7_622.h5')

# Make predictions on the test data
y_pred = model.predict(test_generator)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test_encoded, axis=1)

# Set the figure size
fig, ax = plt.subplots(figsize=(12, 12))

# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred_classes)

# Define the custom labels
custom_labels = ["2", "4", "5", "7", "9", "10", "13"]

# Plot the confusion matrix
sns.heatmap(confusion_mtx, annot=True, fmt='d', cmap='Blues', square=True, ax=ax)

# Set x and y axis labels
ax.set_xticklabels(custom_labels)
ax.set_yticklabels(custom_labels)

plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.title('Confusion Matrix of ResNet to classify 7 stratified clusters')

# Save the plot as a PNG file
plt.savefig('ResNet150V2_str_CM7.png', dpi=300)

plt.show()
# Out:
# 87/87 [==============================] - 17s 182ms/step

# %%
import csv

with open('resnet_str_7.csv', mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['accuracy', 'val_accuracy', 'loss', 'val_loss'])
    rows = zip(history.history['accuracy'], history.history['val_accuracy'], history.history['loss'], history.history['val_loss'])
    writer.writerows(rows)

# %% [markdown]
# ## ResNet150 Stratifided 28 Classes

# %%
import pickle
import tensorflow as tf

# Load the pre-trained ResNet152V2 model
resnet_model = ResNet152V2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

num_classes = 28

import logging
logging.getLogger('tensorflow').setLevel(logging.ERROR)

# Freeze all layers except the last few
for layer in resnet_model.layers[:-10]:
    layer.trainable = False

from tensorflow.keras.optimizers import SGD
from keras.layers.pooling import GlobalAveragePooling2D

# Build the classification head
model = Sequential()
model.add(resnet_model)
model.add(GlobalAveragePooling2D())
model.add(Dense(512, activation='relu'))
#model.add(Dropout(0.5))
model.add(Dense(len(cluster_folders), activation='softmax'))

model.compile(loss='categorical_crossentropy',
              optimizer=SGD(learning_rate=0.01, momentum=0.9),
              metrics=['accuracy'])

# Convert labels to one-hot encoding
from sklearn.preprocessing import LabelBinarizer
lb = LabelBinarizer()
y_train_encoded = lb.fit_transform(y_train)
y_val_encoded = lb.fit_transform(y_val)
y_test_encoded = lb.transform(y_test)

# Use one-hot encoded labels for training and testing
train_generator = train_datagen.flow(X_train, y_train_encoded, batch_size=32)
val_generator = val_datagen.flow(X_val, y_val_encoded, batch_size=32)
test_generator = test_datagen.flow(X_test, y_test_encoded, batch_size=32)

checkpoint = ModelCheckpoint('resnet150_str_28_622.h5',
                             save_best_only=True,
                             save_weights_only=False,
                             monitor='val_accuracy',
                             mode='max',
                             verbose=1)

history = model.fit(train_generator,
                    epochs=50,
                    steps_per_epoch=len(train_generator),
                    validation_data=val_generator,
                    validation_steps=len(val_generator),
                    callbacks=[checkpoint])

# Save the final trained model
model.save('resnet150_str_28_622.h5')

# Save the history object
with open('history_str_28_622.pkl', 'wb') as file_pi:
    pickle.dump(history.history, file_pi)
# Out:
# Epoch 1/50
# 686/686 [==============================] - ETA: 0s - loss: 3.0480 - accuracy: 0.1256
# Epoch 1: val_accuracy improved from -inf to 0.14430, saving model to resnet150_str_28_622.h5
# 686/686 [==============================] - 238s 337ms/step - loss: 3.0480 - accuracy: 0.1256 - val_loss: 2.9790 - val_accuracy: 0.1443
# Epoch 2/50
# 686/686 [==============================] - ETA: 0s - loss: 2.9785 - accuracy: 0.1437
# Epoch 2: val_accuracy improved from 0.14430 to 0.14718, saving model to resnet150_str_28_622.h5
# 686/686 [==============================] - 225s 329ms/step - loss: 2.9785 - accuracy: 0.1437 - val_loss: 2.9550 - val_accuracy: 0.1472
# Epoch 3/50
# 686/686 [==============================] - ETA: 0s - loss: 2.9594 - accuracy: 0.1455
# Epoch 3: val_accuracy improved from 0.14718 to 0.15333, saving model to resnet150_str_28_622.h5
# ...

# %%
# Load the best model
best_model = tf.keras.models.load_model("resnet150_str_28_622.h5")

# Evaluate the best model on test data
loss, accuracy = best_model.evaluate(test_generator)
print(f"Test loss: {loss}, Test accuracy: {accuracy}")
# Out:
# 229/229 [==============================] - 91s 385ms/step - loss: 2.9516 - accuracy: 0.1595
# Test loss: 2.9515559673309326, Test accuracy: 0.15948571264743805

# %%
import matplotlib.pyplot as plt

# Plot the training and validation accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['train', 'val'], loc='upper left')
plt.savefig('ResNet150V2_str_A28.png', dpi=300)
plt.show()

# Plot the training and validation loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['train', 'val'], loc='upper left')
plt.savefig('ResNet150V2_str_L28.png', dpi=300)
plt.show()

# %%
from sklearn.metrics import confusion_matrix
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf

# Load the saved model
model = tf.keras.models.load_model('resnet150_str_28_622.h5')

# Make predictions on the test data
y_pred = model.predict(test_generator)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test_encoded, axis=1)

# Set the figure size
fig, ax = plt.subplots(figsize=(12, 12))

# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred_classes)

# Plot the confusion matrix
sns.heatmap(confusion_mtx, annot=True, fmt='d', cmap='Blues', square=True, ax=ax)
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.title('Confusion Matrix of ResNet to classify 28 stratified clusters')

# Save the plot as a PNG file
plt.savefig('ResNet150V2_str_CM28.png', dpi=300)

plt.show()
# Out:
# 229/229 [==============================] - 85s 361ms/step

# %%
import csv

# Extract the diagonal elements
correct_preds = np.diag(confusion_mtx)

with open('resnet_str_28.csv', mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['accuracy', 'val_accuracy', 'loss', 'val_loss', "correct_predictions"])
    rows = zip(history.history['accuracy'], history.history['val_accuracy'], history.history['loss'], history.history['val_loss'], correct_preds)
    writer.writerows(rows)

# %% [markdown]
# ## ResNet150 Stratifided 14 Classes

# %%
import pickle
import tensorflow as tf

# Load the pre-trained ResNet152V2 model
resnet_model = ResNet152V2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

num_classes = 14

import logging
logging.getLogger('tensorflow').setLevel(logging.ERROR)

# Freeze all layers except the last few
for layer in resnet_model.layers[:-10]:
    layer.trainable = False

from tensorflow.keras.optimizers import SGD
from keras.layers.pooling import GlobalAveragePooling2D

# Build the classification head
model = Sequential()
model.add(resnet_model)
model.add(GlobalAveragePooling2D())
model.add(Dense(512, activation='relu'))
#model.add(Dropout(0.5))
model.add(Dense(len(cluster_folders), activation='softmax'))

model.compile(loss='categorical_crossentropy',
              optimizer=SGD(learning_rate=0.01, momentum=0.9),
              metrics=['accuracy'])

# Convert labels to one-hot encoding
from sklearn.preprocessing import LabelBinarizer
lb = LabelBinarizer()
y_train_encoded = lb.fit_transform(y_train)
y_val_encoded = lb.fit_transform(y_val)
y_test_encoded = lb.transform(y_test)

# Use one-hot encoded labels for training and testing
train_generator = train_datagen.flow(X_train, y_train_encoded, batch_size=32)
val_generator = val_datagen.flow(X_val, y_val_encoded, batch_size=32)
test_generator = test_datagen.flow(X_test, y_test_encoded, batch_size=32)

checkpoint = ModelCheckpoint('resnet150_str_14_622.h5',
                             save_best_only=True,
                             save_weights_only=False,
                             monitor='val_accuracy',
                             mode='max',
                             verbose=1)

history = model.fit(train_generator,
                    epochs=50,
                    steps_per_epoch=len(train_generator),
                    validation_data=val_generator,
                    validation_steps=len(val_generator),
                    callbacks=[checkpoint])

# Save the final trained model
model.save('resnet150_str_14_622.h5')

# Save the history object
with open('history_str_14_622.pkl', 'wb') as file_pi:
    pickle.dump(history.history, file_pi)
# Out:
# Epoch 1/50
# 408/408 [==============================] - ETA: 0s - loss: 2.3907 - accuracy: 0.1656
# Epoch 1: val_accuracy improved from -inf to 0.19118, saving model to resnet150_str_14_622.h5
# 408/408 [==============================] - 149s 349ms/step - loss: 2.3907 - accuracy: 0.1656 - val_loss: 2.3242 - val_accuracy: 0.1912
# Epoch 2/50
# 408/408 [==============================] - ETA: 0s - loss: 2.3271 - accuracy: 0.1876
# Epoch 2: val_accuracy did not improve from 0.19118
# 408/408 [==============================] - 136s 334ms/step - loss: 2.3271 - accuracy: 0.1876 - val_loss: 2.3185 - val_accuracy: 0.1907
# Epoch 3/50
# 408/408 [==============================] - ETA: 0s - loss: 2.3147 - accuracy: 0.1962
# Epoch 3: val_accuracy improved from 0.19118 to 0.20657, saving model to resnet150_str_14_622.h5
# 408/408 [==============================] - 136s 333ms/step - loss: 2.3147 - accuracy: 0.1962 - val_loss: 2.3093 - val_accuracy: 0.2066
# Epoch 4/50
# ...

# %%
# Load the best model
best_model = tf.keras.models.load_model("resnet150_str_14_622.h5")

# Evaluate the best model on test data
loss, accuracy = best_model.evaluate(test_generator)
print(f"Test loss: {loss}, Test accuracy: {accuracy}")
# Out:
# 137/137 [==============================] - 26s 177ms/step - loss: 2.3529 - accuracy: 0.1976
# Test loss: 2.3529245853424072, Test accuracy: 0.19756489992141724

# %%
import matplotlib.pyplot as plt

# Plot the training and validation accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['train', 'val'], loc='upper left')
plt.savefig('ResNet150V2_str_A14.png', dpi=300)
plt.show()

# Plot the training and validation loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['train', 'val'], loc='upper left')
plt.savefig('ResNet150V2_str_L14.png', dpi=300)
plt.show()

# %%
from sklearn.metrics import confusion_matrix
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf

# Load the saved model
model = tf.keras.models.load_model('resnet150_str_14_622.h5')

# Convert labels to one-hot encoding
from sklearn.preprocessing import LabelBinarizer
lb = LabelBinarizer()
y_train_encoded = lb.fit_transform(y_train)
y_test_encoded = lb.transform(y_test)

# Use one-hot encoded labels for training and testing
train_generator = train_datagen.flow(X_train, y_train_encoded, batch_size=32)
test_generator = test_datagen.flow(X_test, y_test_encoded, batch_size=32)

# Make predictions on the test data
y_pred = model.predict(test_generator)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test_encoded, axis=1)

# Define the cluster labels
cluster_labels = ['1', '2', '3', '4', '5', '6', '9', '12', '21', '22', '23', '24', '26', '28']

# Set the figure size
fig, ax = plt.subplots(figsize=(12, 12))

# Generate the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred_classes)

# Plot the confusion matrix
sns.heatmap(confusion_mtx, annot=True, fmt='d', cmap='Blues', square=True, ax=ax)

# Set x and y axis labels
ax.set_xticklabels(cluster_labels)
ax.set_yticklabels(cluster_labels)

plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.title('Confusion Matrix of ResNet to classify 14 stratified clusters')

# Save the plot as a PNG file
plt.savefig('ResNet150V2_str_CM14.png', dpi=300)

plt.show()
# Out:
# 137/137 [==============================] - 27s 182ms/step

# %%
import csv

# Extract the diagonal elements
correct_preds = np.diag(confusion_mtx)

with open('resnet_str_14.csv', mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['accuracy', 'val_accuracy', 'loss', 'val_loss', "correct_predictions"])
    rows = zip(history.history['accuracy'], history.history['val_accuracy'], history.history['loss'], history.history['val_loss'], correct_preds)
    writer.writerows(rows)

# %%
from PIL import Image
from PIL import ImageFilter

# Load the image
image = Image.open('cell_184.png')

# Apply convolution filter
filtered_image = image.filter(ImageFilter.CONTOUR)

# Save the processed image
filtered_image.save('cell_184_conv.png')

# %%
from PIL import Image
from PIL import ImageFilter

# Load the image
image = Image.open('cell_184_conv.png')

# Apply convolution filter
filtered_image = image.filter(ImageFilter.CONTOUR)

# Save the processed image
filtered_image.save('cell_184_conv_conv.png')

# %%
from PIL import Image
from PIL import ImageFilter

# Load the image
image = Image.open('cell_184_conv_conv.png')

# Apply convolution filter
filtered_image = image.filter(ImageFilter.CONTOUR)

# Save the processed image
filtered_image.save('cell_184_conv_conv_conv.png')

# %%
import torch
from torchvision import transforms
from torchvision.models import resnet152
from PIL import Image

# Load the image
image = Image.open('cell_184.png')

# Convert the image to RGB format
image_rgb = image.convert('RGB')

# Define transformation pipeline
preprocess = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# Preprocess the image
input_tensor = preprocess(image_rgb)

# Expand dimensions to create a batch
input_batch = input_tensor.unsqueeze(0)

# Load pre-trained ResNet model
model = resnet152(pretrained=True)
model.eval()

# Process the image through ResNet
with torch.no_grad():
    output = model(input_batch)

# Get the processed image tensor
processed_tensor = output.squeeze(0)

# Convert the tensor to an RGB PIL image
processed_image = transforms.ToPILImage()(processed_tensor.cpu())

# Save the processed image
processed_image.save('cell_184_torch.png')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27000\3445321263.py in <module>
#      35
#      36 # Convert the tensor to an RGB PIL image
# ---> 37 processed_image = transforms.ToPILImage()(processed_tensor.cpu())
#      38
#      39 # Save the processed image
#
# D:\Anaconda3\lib\site-packages\torchvision\transforms\transforms.py in __call__(self, pic)
#     225
#     226         """
# --> 227         return F.to_pil_image(pic, self.mode)
#     228
#     229     def __repr__(self) -> str:
#
# D:\Anaconda3\lib\site-packages\torchvision\transforms\functional.py in to_pil_image(pic, mode)
#     261     elif isinstance(pic, torch.Tensor):
#     262         if pic.ndimension() not in {2, 3}:
# --> 263             raise ValueError(f"pic should be 2/3 dimensional. Got {pic.ndimension()} dimensions.")
#     264
# ...
